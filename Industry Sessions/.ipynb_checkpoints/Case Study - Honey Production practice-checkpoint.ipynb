# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mydata = pd.read_csv('honeyproduction.csv')

# %%
mydata.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
mydata.describe().transpose()
# Out:
#              count          mean           std        min          25%  \
# numcol       626.0  6.028435e+04  9.107709e+04    2000.00    9000.0000
# yieldpercol  626.0  6.200958e+01  1.945875e+01      19.00      48.0000
# totalprod    626.0  4.169086e+06  6.883847e+06   84000.00  475000.0000
# stocks       626.0  1.318859e+06  2.272964e+06    8000.00  143000.0000
# priceperlb   626.0  1.409569e+00  6.385989e-01       0.49       0.9325
# prodvalue    626.0  4.715741e+06  7.976110e+06  162000.00  759250.0000
# year         626.0  2.004864e+03  4.317306e+00    1998.00    2001.0000
#
#                     50%         75%          max
# numcol         26000.00    63750.00    510000.00
# yieldpercol       60.00       74.00       136.00
# totalprod    1533000.00  4175250.00  46410000.00
# stocks        439500.00  1489500.00  13800000.00
# priceperlb         1.36        1.68         4.15
# prodvalue    1841500.00  4703250.00  69615000.00
# year            2005.00     2009.00      2012.00

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
# state          626 non-null object
# numcol         626 non-null float64
# yieldpercol    626 non-null int64
# totalprod      626 non-null float64
# stocks         626 non-null float64
# priceperlb     626 non-null float64
# prodvalue      626 non-null float64
# year           626 non-null int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %%
mydata['state'].nunique()
# Out:
# 44

# %%
mydata['state'].unique()
# Out:
# array(['AL', 'AZ', 'AR', 'CA', 'CO', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN',
#        'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MI', 'MN', 'MS', 'MO', 'MT',
#        'NE', 'NV', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA',
#        'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'SC'],
#       dtype=object)

# %%
mydata.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
mydata.groupby(['state']).mean().round()
# mydata[['state', 'totalprod']].groupby('state').mean().round()
# Out:
#          numcol  yieldpercol   totalprod     stocks  priceperlb   prodvalue  \
# state
# AL      11933.0         68.0    825467.0   158800.0         1.0   1001933.0
# AR      36800.0         74.0   2810400.0   992667.0         1.0   2684400.0
# AZ      33667.0         60.0   2032267.0   877000.0         1.0   2111800.0
# CA     406667.0         56.0  23169000.0  6453800.0         1.0  24359333.0
# CO      28000.0         63.0   1750600.0   815267.0         1.0   2090267.0
# FL     195200.0         83.0  16469867.0  2209600.0         1.0  16615267.0
# GA      60400.0         55.0   3299933.0   352267.0         1.0   3867533.0
# HI       8733.0         98.0    843133.0   170200.0         2.0   1404200.0
# IA      31467.0         66.0   2080000.0  1129933.0         1.0   2588333.0
# ID      99400.0         44.0   4410667.0  1875933.0         1.0   4762067.0
# IL       8067.0         62.0    498333.0   209933.0         2.0   1007533.0
# ...

# %%
mydata['year'].unique()
print(mydata['year'].unique()[0])
print(mydata['year'].unique()[-1])
# Out:
# 1998
# 2012

# %%
mydata.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
mydata[mydata['totalprod'] == mydata['totalprod'].max()]
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 532    ND  510000.0           91  46410000.0  12995000.0         1.5
#
#       prodvalue  year
# 532  69615000.0  2010

# %%
mydata.groupby(['year'],as_index=False).mean().round()[['yieldpercol','year']]
# Out:
#     yieldpercol  year
# 0          70.0  1998
# 1          65.0  1999
# 2          68.0  2000
# 3          65.0  2001
# 4          67.0  2002
# 5          63.0  2003
# 6          65.0  2004
# 7          64.0  2005
# 8          62.0  2006
# 9          59.0  2007
# 10         61.0  2008
# 11         54.0  2009
# 12         56.0  2010
# 13         55.0  2011
# 14         55.0  2012

# %%
sns.pairplot(data=mydata[['numcol','yieldpercol','totalprod','stocks','priceperlb','prodvalue']])

# %%
corr = mydata[['numcol','yieldpercol','totalprod','stocks','priceperlb','prodvalue']].corr()
corr
# Out:
#                numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue
# numcol       1.000000     0.243515   0.953594  0.825929   -0.232701   0.912796
# yieldpercol  0.243515     1.000000   0.396252  0.367812   -0.358646   0.278977
# totalprod    0.953594     0.396252   1.000000  0.878830   -0.264499   0.907236
# stocks       0.825929     0.367812   0.878830  1.000000   -0.305867   0.728560
# priceperlb  -0.232701    -0.358646  -0.264499 -0.305867    1.000000  -0.089567
# prodvalue    0.912796     0.278977   0.907236  0.728560   -0.089567   1.000000

# %%
sns.heatmap(corr,cmap='coolwarm',annot=True)

# %%
sns.pointplot(data=mydata,x='year',y='totalprod')
plt.tight_layout()

# %%
g = sns.FacetGrid(data=mydata,col='totalprod',col_wrap=10,)
g.map()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-c9bc09a282a0> in <module>
# ----> 1 sns.FacetGrid(data=mydata,col='totalprod',col_wrap=10)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     373
#     374         # Make the axes look good
# --> 375         fig.tight_layout()
#     376         if despine:
#     377             self.despine()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2473         kwargs = get_tight_layout_figure(
# ...
